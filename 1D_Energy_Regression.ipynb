# %%
import numpy as np
import matplotlib.pyplot as plt
import uproot
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import AdaBoostRegressor
import pandas
from sklearn import linear_model

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import AdaBoostRegressor

df = pandas.read_csv("dataset.csv")
N = df[['ntotal']]
n = df[['nmax']]

y = df['Energy']

regr = linear_model.LinearRegression()
regr.fit(N, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
newfilepath = "FASERnu1-100.root"
newfile = uproot.open(newfilepath)
earray = [newfile["FASERnu;1"]["x"].array()]
for i in range(1000):
    print(len(earray[0][i]))
# Out:
# 43480
# 43333
# 43506
# 43794
# 43350
# 43737
# 43544
# 43663
# 44072
# 43217
# 43140
# 43687
# 43858
# 43166
# 43740
# 43969
# 43764
# 43802
# 43927
# 43649
# 43935
# 43549
# 43808
# 44110
# 43659
# 43727
# 43797
# 43693
# 43947
# 43585
# 43236
# 43775
# 43660
# 43469
# 44098
# 43908
# 43739
# 44206
# 43767
# 43792
# 43703
# 43552
# 43543
# 43544
# 43505
# 44199
# 44038
# 43333
# 43285
# 43955
# 43578
# 43558
# 44051
# 43808
# 43693
# 43468
# 43703
# 43839
# 43420
# 43727
# 43833
# 43003
# 44166
# 44102
# 43566
# 44028
# 43599
# 43864
# 43662
# 43229
# 43282
# 44068
# 43616
# 43474
# 43530
# 44204
# 43984
# 43279
# 43942
# 43192
# 43503
# 43781
# 43159
# 43050
# 43674
# 43343
# 43461
# 43787
# 43304
# 43655
# 43769
# 43804
# 44061
# 44061
# 43382
# 43739
# 43931
# 43161
# 44151
# 43911
# 43579
# 43612
# 43936
# 43661
# 44425
# 43488
# 43989
# 43504
# 43585
# 43498
# 43919
# 43938
# 44249
# 43515
# 43535
# 43796
# 43353
# 43733
# 44093
# 43695
# 43771
# 43586
# 43825
# 43452
# 43683
# ...

# %%
newfilepath = "FASERnu1-100.root"
newfile = uproot.open(newfilepath)
#earray = [newfile["FASERnu;1"]["Enu_nuEvt"].array()]
izarray = [newfile["FASERnu;1"]["iz"].array()]
izmax = np.zeros((1000,1))
nmax = np.zeros((1000,1))
total = np.zeros((1000,1))
test = np.zeros((1000,3))
for i in range(1000):
        h = np.unique(izarray[0][i],return_counts = True)
        list = h[1]
        izmax[i][0] = np.exp(list.argmax()/3.85398068)
        nmax[i][0] = list[list.argmax()]
        total[i][0] = len(izarray[0][i])
        test[i][0] = total[i][0]
        test[i][1] = nmax[i][0]
        test[i][2] = izmax[i][0]
#        print(test[i][0], test[i][1], test[i][2])
    #print(len(izarray[0][i]))
        #print(list)
reco = np.zeros((1000,2))
for i in range(1000):
    reco[i][0] = 1000000
    reco[i][1] = regr.predict([[test[i][0]]])
    print(reco[i][1])
# Out:
# 99514.79929198774
# 99574.28740191314
# 99217.35874236083
# 100233.23261954817
# 99988.41616716294
# 98796.36596442733
# 100869.29779490423
# 99178.46267048654
# 99679.53559639651
# 99489.63124548085
# 100251.53665337137
# 100537.5371818588
# 99661.23156257332
# 98913.0541800502
# 100928.78590482961
# 99901.47200650275
# 100555.841215682
# 100102.81637855791
# 99672.67158371281
# 99571.99939768524
# 100265.26467873876
# 98736.87785450193
# 100494.06510152871
# 100956.2419555644
# 100791.50565115565
# 99924.35204878174
# 100079.93633627892
# 100240.09663223187
# 100002.14419253034
# 100583.29726641679
# 100379.66489013375
# 99755.03973591719
# 98956.52626038028
# 100189.76053921808
# 99661.23156257332
# 99933.50406569336
# 100109.6803912416
# 100633.63335943058
# 100601.60130023998
# 100228.65661109237
# 100025.02423480933
# 99926.64005300964
# 100164.59249271119
# 99658.94355834542
# 100107.39238701371
# 99068.63846754735
# 101175.89036144275
# 101159.87433184746
# ...
